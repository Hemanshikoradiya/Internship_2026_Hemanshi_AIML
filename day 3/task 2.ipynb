# %%
students = {
    "Hemanshi": 85,
    "Rajvi": 90,
    "Devanshi": 78
}

print("Student Names:")
for name in students:
    print(name)

print("\nStudent Marks:")
for marks in students.values():
    print(marks)
# Out:
# Student Names:
# Hemanshi
# Rajvi
# Devanshi
#
# Student Marks:
# 85
# 90
# 78
